# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('GIH_Train.csv')
train.head(10)
# Out:
#    InvoiceNo  StockCode  Description  Quantity          InvoiceDate  \
# 0       6141       1583          144         3  2011-05-06 16:54:00
# 1       6349       1300         3682         6  2011-05-11 07:35:00
# 2      16783       2178         1939         4  2011-11-20 13:20:00
# 3      16971       2115         2983         1  2011-11-22 12:07:00
# 4       6080       1210         2886        12  2011-05-06 09:00:00
# 5      17388        495         3247         5  2011-11-27 12:52:00
# 6      18494        165         3377         1  2011-12-08 20:01:00
# 7      17109       2597         3435         1  2011-11-23 12:40:00
# 8      17143       1945         2352         1  2011-11-23 14:07:00
# 9       8422       3311         2502         6  2011-06-22 10:11:00
#
#    UnitPrice  CustomerID  Country
# 0       3.75     14056.0       35
# 1       1.95     13098.0       35
# 2       5.95     15044.0       35
# 3       0.83     15525.0       35
# 4       1.65     13952.0       35
# ...

# %%
train['Quantity'] = train['Quantity'].abs()

# %%
print(train['Country'].unique())
print(train['Country'].value_counts())
# Out:
# [35 23 13  0 10 14 24  3 26 25  6 30 16 18 15 12  1 32  7 31  5 17  9 36
#  34 19 29 33  8 22 11 21  4 27 20  2 28]
# 35    253253
# 14      6653
# 13      5946
# 10      5244
# 30      1776
# 23      1680
# 3       1435
# 32      1293
# 26      1049
# 0        883
# 24       766
# 18       561
# 6        537
# 12       489
# 7        424
# 31       325
# 1        303
# 9        273
# 25       244
# 19       238
# 33       210
# 17       185
# 36       171
# 29       152
# 16       132
# 5        106
# 15       101
# 22        89
# 34        52
# 27        47
# 11        40
# 20        34
# 8         26
# 21        25
# 4         20
# 2         10
# 28         8
# Name: Country, dtype: int64

# %%
#train.loc[train['Quantity']>9500,'Quantity']=6.5

# %%
#train.loc[train['UnitPrice']>8500,'UnitPrice']=3.5

# %%
x = train.loc[:,('StockCode','Quantity','Description','Country','InvoiceNo','CustomerID')]
y = train.loc[:,('UnitPrice')]

# %%
train.nunique()
# Out:
# InvoiceNo      20971
# StockCode       3619
# Description     3819
# Quantity         270
# InvoiceDate    19451
# UnitPrice        524
# CustomerID      4339
# Country           37
# dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284780 entries, 0 to 284779
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    284780 non-null  int64
#  1   StockCode    284780 non-null  int64
#  2   Description  284780 non-null  int64
#  3   Quantity     284780 non-null  int64
#  4   InvoiceDate  284780 non-null  object
#  5   UnitPrice    284780 non-null  float64
#  6   CustomerID   284780 non-null  float64
#  7   Country      284780 non-null  int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 17.4+ MB

# %%
test = pd.read_csv('GIH_Test.csv')
test.head()
# Out:
#    InvoiceNo  StockCode  Description  Quantity          InvoiceDate  \
# 0       3139       1709         1079         3  2011-02-22 15:22:00
# 1        617        510         3457         1  2010-12-08 12:46:00
# 2      14653        604          694        36  2011-10-25 13:53:00
# 3       8634       1478         3473         2  2011-06-27 12:38:00
# 4      15546       3216          871         1  2011-11-06 16:14:00
#
#    CustomerID  Country
# 0     16161.0       35
# 1     17341.0       35
# 2     15158.0       35
# 3     16033.0       35
# 4     15351.0       35

# %%
test['Quantity'] = test['Quantity'].abs()

# %%
x_test = test.loc[:,('StockCode','Quantity','Description','Country','InvoiceNo','CustomerID')]

# %%
# from sklearn.ensemble import RandomForestRegressor
# model = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=103, n_jobs=-2, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# model.fit(x,y).score(x,y)

# %%
from catboost import CatBoostRegressor
CB = CatBoostRegressor(iterations=None,
                        learning_rate=0.49,
                        depth=None,
                        l2_leaf_reg=None,
                        model_size_reg=None,
                        rsm=None,
                        loss_function='RMSE',
                        border_count=None,
                        feature_border_type=None,
                        per_float_feature_quantization=None,
                        input_borders=None,
                        output_borders=None,
                        fold_permutation_block=None,
                        od_pval=None,
                        od_wait=None,
                        od_type=None,
                        nan_mode=None,
                        counter_calc_method=None,
                        leaf_estimation_iterations=None,
                        leaf_estimation_method=None,
                        thread_count=None,
                        random_seed=None,
                        use_best_model=None,
                        best_model_min_trees=None,
                        verbose=None,
                        silent=None,
                        logging_level=None,
                        metric_period=None,
                        ctr_leaf_count_limit=None,
                        store_all_simple_ctr=None,
                        max_ctr_complexity=None,
                        has_time=None,
                        allow_const_label=None,
                        one_hot_max_size=None,
                        random_strength=None,
                        name=None,
                        ignored_features=None,
                        train_dir=None,
                        custom_metric=None,
                        eval_metric=None,
                        bagging_temperature=None,
                        save_snapshot=None,
                        snapshot_file=None,
                        snapshot_interval=None,
                        fold_len_multiplier=None,
                        used_ram_limit=None,
                        gpu_ram_part=None,
                        pinned_memory_size=None,
                        allow_writing_files=None,
                        final_ctr_computation_mode=None,
                        approx_on_full_history=None,
                        boosting_type=None,
                        simple_ctr=None,
                        combinations_ctr=None,
                        per_feature_ctr=None,
                        ctr_target_border_count=None,
                        task_type=None,
                        device_config=None,                        
                        devices=None,
                        bootstrap_type=None,
                        subsample=None,                        
                        sampling_unit=None,
                        dev_score_calc_obj_block_size=None,
                        max_depth=None,
                        n_estimators=None,
                        num_boost_round=None,
                        num_trees=None,
                        colsample_bylevel=None,
                        random_state=None,
                        reg_lambda=None,
                        objective=None,
                        eta=None,
                        max_bin=None,
                        gpu_cat_features_storage=None,
                        data_partition=None,
                        metadata=None,
                        early_stopping_rounds=None,
                        cat_features=None,
                        grow_policy=None,
                        min_data_in_leaf=None,
                        min_child_samples=2,
                        max_leaves=None,
                        num_leaves=None,
                        score_function=None,
                        leaf_estimation_backtracking=None,
                        ctr_history_unit=None,
                        monotone_constraints=None,
                        feature_weights=None,
                        penalties_coefficient=None,
                        first_feature_use_penalties=None,
                        model_shrink_rate=None,
                        model_shrink_mode=None,
                        langevin=None,
                        diffusion_temperature=None,
                        boost_from_average=None)


CB.fit(x, y).score(x, y)
# Out:
# 0:	learn: 69.8474671	total: 25.1ms	remaining: 25.1s
# 1:	learn: 62.4970262	total: 48.1ms	remaining: 24s
# 2:	learn: 56.1115280	total: 71.3ms	remaining: 23.7s
# 3:	learn: 54.9566105	total: 93.3ms	remaining: 23.2s
# 4:	learn: 49.6216747	total: 120ms	remaining: 23.9s
# 5:	learn: 45.0928868	total: 148ms	remaining: 24.5s
# 6:	learn: 41.1846906	total: 172ms	remaining: 24.4s
# 7:	learn: 37.9158796	total: 193ms	remaining: 24s
# 8:	learn: 37.2746849	total: 215ms	remaining: 23.7s
# 9:	learn: 34.5485485	total: 246ms	remaining: 24.3s
# 10:	learn: 33.4178729	total: 269ms	remaining: 24.2s
# 11:	learn: 33.2235539	total: 292ms	remaining: 24s
# 12:	learn: 30.9088234	total: 315ms	remaining: 23.9s
# 13:	learn: 29.0361211	total: 341ms	remaining: 24s
# 14:	learn: 27.4980781	total: 363ms	remaining: 23.9s
# 15:	learn: 26.8964466	total: 385ms	remaining: 23.7s
# 16:	learn: 26.6238211	total: 407ms	remaining: 23.5s
# 17:	learn: 26.4372229	total: 435ms	remaining: 23.7s
# ...

# %%
y_predict = CB.predict(x_test)

# %%
final = pd.DataFrame(y_predict)
final
# Out:
#                 0
# 0        1.554934
# 1        2.639972
# 2        2.887806
# 3        1.584551
# 4       11.552438
# ...           ...
# 122044   0.595769
# 122045   1.577430
# 122046   0.999161
# 122047   6.115602
# 122048   3.751632
#
# [122049 rows x 1 columns]

# %%
#final.to_csv('C:/Users/gaurav sahani/Desktop/GIH_CB_SCCQD.csv',index = False)
